# %%
#Podemos descargar datos de empresas del dataset Forbes2000 (paquete HSAUR) mediante
#get_rdataset(). Encontraremos un ranking de empresas categorizadas por sector, y con datos
#de su país, ventas, beneficios, recursos y valor de mercado.

# %%
import numpy as num
import pandas as panda
import matplotlib.pyplot as plt
import scipy as scipy
import statsmodels.api as stat 
import statsmodels.formula.api as statf

# %%
forbes = sm.datasets.get_rdataset("Forbes2000","HSAUR")
forbes = forbes.data

# %%
forbes.head(999999999999999999)
# Out:
#       rank                       name                      country  \
# 0        1                  Citigroup                United States
# 1        2           General Electric                United States
# 2        3        American Intl Group                United States
# 3        4                 ExxonMobil                United States
# 4        5                         BP               United Kingdom
# 5        6            Bank of America                United States
# 6        7                 HSBC Group               United Kingdom
# 7        8               Toyota Motor                        Japan
# 8        9                 Fannie Mae                United States
# 9       10            Wal-Mart Stores                United States
# 10      11                        UBS                  Switzerland
# 11      12                  ING Group                  Netherlands
# 12      13    Royal Dutch/Shell Group  Netherlands/ United Kingdom
# ...

# %%
rank_max= forbes["rank"].max()
print rank_max
# Out:
# 2000

# %%
# OK, tenemos 2000 filas en el fichero

# %%
#Seleccionar del dataframe los nombres de empresa que incluyen "elect" (sin tener en
#cuenta mayúsculas). Intentamos con esto obtener empresas “del sector de la
#electricidad” de forma aproximada.

# %%
elect = forbes [forbes.name.str.contains("elect", case=False)==True]
elect.head(99999)
# Out:
#       rank                       name          country  \
# 1        2           General Electric    United States
# 44      45        Samsung Electronics      South Korea
# 71      72       Tokyo Electric Power            Japan
# 151    152       Korea Electric Power      South Korea
# 156    157      Kansai Electric Power            Japan
# 170    171       Chubu Electric Power            Japan
# 219    220           Emerson Electric    United States
# 280    281      Tohoku Electric Power            Japan
# 284    285      Kyushu Electric Power            Japan
# 322    323         Schneider Electric           France
# 414    415   Matsushita Electric Indl            Japan
# 424    425         STMicroelectronics      Switzerland
# 433    434           Electrolux Group           Sweden
# 439    440     Chugoku Electric Power            Japan
# 567    568          American Electric    United States
# 585    586        Mitsubishi Electric            Japan
# ...

# %%
numero_lineas=elect.shape[0]
print numero_lineas
# Out:
# 50

# %%
numero_Columnas=elect.shape[1]
print numero_Columnas
# Out:
# 8

# %%
# Ok ahora en elecct tenemos 50 filas y 8 coluumnas

# %%
#Utilizando como índice el país y la categoría y ordenándolo (sort_index), encontrar el
#valor de mercado de las empresas japonesas y estadounidenses.

# %%
Valor_mercado = elect.set_index(["country", "category"])
Valor_mercado.sort_index(inplace=True)
Valor_mercado.head(15)
# Out:
#                                               rank                       name  \
# country         category
# Austria         Utilities                     1184  Verbund-Austrian Electric
# China           Utilities                     1842   Guangdong Electric Power
# France          Capital goods                  323         Schneider Electric
# Hong Kong/China Capital goods                 1582  Johnson Electric Holdings
#                 Utilities                      811          Hongkong Electric
# Japan           Business services & supplies  1333              Alps Electric
#                 Business services & supplies  1461      Nippon Electric Glass
#                 Business services & supplies  1468      Oki Electric Industry
#                 Business services & supplies  1997          Yokogawa Electric
#                 Capital goods                  586        Mitsubishi Electric
#                 Capital goods                  635  Matsushita Electric Works
# ...

# %%
valor_japon = Valor_mercado.loc["Japan"]
valor_eeuu = Valor_mercado.loc["United States"]

# %%
valor_japon.head(5)
# Out:
#                               rank                   name  sales  profits  \
# category
# Business services & supplies  1333          Alps Electric   5.09     0.15
# Business services & supplies  1461  Nippon Electric Glass   2.78     0.12
# Business services & supplies  1468  Oki Electric Industry   4.95    -0.06
# Business services & supplies  1997      Yokogawa Electric   2.78    -0.22
# Capital goods                  586    Mitsubishi Electric  30.79    -0.10
#
#                               assets  marketvalue
# category
# Business services & supplies    4.00         2.30
# Business services & supplies    4.15         3.25
# Business services & supplies    5.05         2.69
# Business services & supplies    2.96         3.29
# Capital goods                  26.24        10.28

# %%
valor_eeuu.head(5)
# Out:
#                                   rank                 name   sales  profits  \
# category
# Conglomerates                        2     General Electric  134.19    15.59
# Conglomerates                      220     Emerson Electric   14.33     1.12
# Health care equipment & services  1396      Thermo Electron    2.10     0.20
# Media                              622   Hughes Electronics   10.12    -0.30
# Software & services                647  Electronic Data Sys   21.48    -0.27
#
#                                   assets  marketvalue
# category
# Conglomerates                     626.93       328.54
# Conglomerates                      15.71        26.88
# Health care equipment & services    3.39         4.63
# Media                              18.95        23.56
# Software & services                18.28         9.98

# %%
erase_una_vez_valor_mercado_total_japon= valor_japon ["marketvalue"].sum()
print erase_una_vez_valor_mercado_total_japon
# Out:
# 215.1

# %%
erase_una_vez_valor_mercado_media_japon= valor_japon ["marketvalue"].mean()
print erase_una_vez_valor_mercado_media_japon
# Out:
# 7.96666666667

# %%
valor_mercado_total_eeuu= valor_eeuu ["marketvalue"].sum()
print valor_mercado_total_eeuu
# Out:
# 424.69

# %%
valor_mercado_medio_eeuu= valor_eeuu ["marketvalue"].mean()
print valor_mercado_medio_eeuu
# Out:
# 47.1877777778

# %%
valor_medio_japonyeeuu = valor_mercado_medio_eeuu + erase_una_vez_valor_mercado_media_japon
print valor_medio_japonyeeuu
# Out:
# 55.1544444444

# %%
valor_total_japonyeeuu = valor_mercado_total_eeuu + erase_una_vez_valor_mercado_total_japon
print valor_total_japonyeeuu
# Out:
# 639.79

# %%
#Sobre el mismo subconjunto de empresas eléctricas, obtener el país donde el sector de
#utilities tiene mayor valor de mercado medio en sus empresas.

# %%
elect.head(2)
# Out:
#     rank                 name        country        category   sales  profits  \
# 1      2     General Electric  United States   Conglomerates  134.19    15.59
# 44    45  Samsung Electronics    South Korea  Semiconductors   50.22     5.95
#
#     assets  marketvalue
# 1   626.93       328.54
# 44   54.58        72.72

# %%
indexado= elect.set_index(["category"])
indexado.head(5)
# Out:
#                 rank                   name        country   sales  profits  \
# category
# Conglomerates      2       General Electric  United States  134.19    15.59
# Semiconductors    45    Samsung Electronics    South Korea   50.22     5.95
# Utilities         72   Tokyo Electric Power          Japan   41.62     1.40
# Utilities        152   Korea Electric Power    South Korea   18.01     2.57
# Utilities        157  Kansai Electric Power          Japan   22.12     0.68
#
#                 assets  marketvalue
# category
# Conglomerates   626.93       328.54
# Semiconductors   54.58        72.72
# Utilities       116.68        30.63
# Utilities        58.38        11.84
# Utilities        60.52        17.56

# %%
utilities = indexado.loc["Utilities"]

# %%
utilities_ordenado = utilities.sort_values("country",ascending=False)

# %%
utilities_ordenado.head(115)
# Out:
#            rank                       name          country  sales  profits  \
# category
# Utilities   568          American Electric    United States  15.58    -0.16
# Utilities  1836          Hawaiian Electric    United States   1.76     0.10
# Utilities   152       Korea Electric Power      South Korea  18.01     2.57
# Utilities    72       Tokyo Electric Power            Japan  41.62     1.40
# Utilities   157      Kansai Electric Power            Japan  22.12     0.68
# Utilities   171       Chubu Electric Power            Japan  18.41     0.90
# Utilities   281      Tohoku Electric Power            Japan  13.48     0.52
# Utilities   285      Kyushu Electric Power            Japan  12.02     0.54
# Utilities   440     Chugoku Electric Power            Japan   8.54     0.37
# Utilities   728     Shikoku Electric Power            Japan   4.95     0.22
# Utilities   799    Hokkaido Electric Power            Japan   4.39     0.22
# ...

# %%
eeuu_utilities = utilities_ordenado[(utilities_ordenado.country=="United States")]
mean_eeuu= eeuu_utilities["marketvalue"].mean()
mean_eeuu
# Out:
# 7.575

# %%
japon_utilities = utilities_ordenado[(utilities_ordenado.country=="Japan")]
mean_japon= japon_utilities["marketvalue"].mean()
mean_japon
# Out:
# 11.054444444444446

# %%
# el valor medio de las utilities de EEUU es 7.575
# el valor medio de las utilities de Corea del Sur es 11.84 (solo hay una)
# el de Japón (mira que esta lejos Japón) es 11.054444444444446
# el de Hong Kong es 9.04
# el valor medio de las utilities de china es 3.39 (solo hay una)
# el de Austria es 	4.28
#
# so the winner is.....

# Corea del Sur (la de Kim Jong-un, NO, la otra, más abajo)

# %%
# Volviendo al dataset original, obtener las empresas españolas.

# %%
forbes.head(3)
# Out:
#    rank                 name        country       category   sales  profits  \
# 0     1            Citigroup  United States        Banking   94.71    17.85
# 1     2     General Electric  United States  Conglomerates  134.19    15.59
# 2     3  American Intl Group  United States      Insurance   76.66     6.46
#
#     assets  marketvalue
# 0  1264.03       255.30
# 1   626.93       328.54
# 2   647.66       194.87

# %%
iberos = forbes[forbes.country=="Spain"]
iberos
# Out:
#       rank                       name country                       category  \
# 38      39    Banco Santander Central   Spain                        Banking
# 56      57  BBVA-Banco Bilbao Vizcaya   Spain                        Banking
# 108    109                 Repsol-YPF   Spain           Oil & gas operations
# 114    115               Endesa Group   Spain                      Utilities
# 188    189                  Iberdrola   Spain                      Utilities
# 378    379      Banco Popular Espaqol   Spain                        Banking
# 408    409                 Telefsnica   Spain    Telecommunications services
# 462    463            Gas Natural SDG   Spain                      Utilities
# 472    473                    Altadis   Spain           Food drink & tobacco
# 529    530               Unisn Fenosa   Spain                      Utilities
# 532    533                      Cepsa   Spain           Oil & gas operations
# ...

# %%
# Indexar el dataframe anterior por beneficios (profits) y obtener los nombres y rangos de
# las que tengan un beneficio nulo o negativo. Nota: intenta indexar de manera mixta con
# números (filas) y etiquetas columnas), hay una operación específica para esto en
# pandas.

# %%
# una forma muy rupestre de hacerlo:

iberos_ordenado=iberos.sort_values("profits",ascending=True)

iberos_ordenado.head(5)
# Out:
#       rank                name country                     category  sales  \
# 408    409          Telefsnica   Spain  Telecommunications services  29.84
# 1992  1993           Sogecable   Spain                        Media   1.03
# 1892  1893        Banco Pastor   Spain                      Banking   0.49
# 951    952  Corporation Mapfre   Spain                    Insurance   5.87
# 1931  1932              Gamesa   Spain                Capital goods   1.15
#
#       profits  assets  marketvalue
# 408     -5.86   60.65        86.39
# 1992    -0.06    1.53         6.02
# 1892     0.08   13.12         1.79
# 951      0.12   15.45         2.73
# 1931     0.14    2.04         3.02

# %%
index_iberos = iberos_ordenado.set_index(["profits"])
index_iberos.head(4)
# Out:
#          rank                name country                     category  sales  \
# profits
# -5.86     409          Telefsnica   Spain  Telecommunications services  29.84
# -0.06    1993           Sogecable   Spain                        Media   1.03
#  0.08    1893        Banco Pastor   Spain                      Banking   0.49
#  0.12     952  Corporation Mapfre   Spain                    Insurance   5.87
#
#          assets  marketvalue
# profits
# -5.86     60.65        86.39
# -0.06      1.53         6.02
#  0.08     13.12         1.79
#  0.12     15.45         2.73

# %%
# y con esto  ya sabemmos cuales son 
# negativos Telefssssssssnica y sogecable

# %%
# pero creo que pides esto

iberos_profif = iberos.set_index(["profits"])
iberos_profif.sort_index(inplace=True)
iberos_profif.ix[:0,["rank","name"]]
# Out:
#          rank        name
# profits
# -5.86     409  Telefsnica
# -0.06    1993   Sogecable
